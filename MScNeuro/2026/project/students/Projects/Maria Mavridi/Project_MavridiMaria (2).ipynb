# %% [markdown]
# # Exams
# ## NAME: Maria Mavridi

# %% [markdown]
# ## Loading the Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# %%
# Load the dataset
infile = "https://raw.githubusercontent.com/cgenomicslab/Courses/refs/heads/main/MScNeuro/2026/data/mouse_cognition.csv"
#infile = "/Users/alxndrs/Documents/courses/Courses/MScNeuro/2026/data/mouse_cognition.csv"
mice = pd.read_csv(infile)

mice.head(30)
# Out:
#    mouse_id strain  maze_test  object_recognition  fear_conditioning  \
# 0      M001      A         78                  72                 65
# 1      M002      A         82                  75                 68
# 2      M003      A         75                  70                 62
# 3      M004      A         80                  74                 66
# 4      M005      A         77                  71                 64
# 5      M006      A         83                  76                 69
# 6      M007      A         76                  69                 63
# 7      M008      A         79                  73                 65
# 8      M009      A         81                  74                 67
# 9      M010      A         74                  68                 61
# 10     M011      A         78                  71                 64
# 11     M012      A         80                  73                 66
# 12     M013      A         76                  70                 63
# 13     M014      A         82                  75                 68
# 14     M015      A         79                  72                 65
# 15     M016      B         65                  80                 70
# 16     M017      B         68                  83                 73
# 17     M018      B         62                  77                 67
# 18     M019      B         66                  81                 71
# 19     M020      B         64                  79                 69
# 20     M021      B         69                  84                 74
# 21     M022      B         61                  76                 66
# 22     M023      B         67                  82                 72
# 23     M024      B         70                  85                 75
# 24     M025      B         60                  75                 65
# 25     M026      B         66                  80                 70
# 26     M027      B         68                  82                 72
# 27     M028      B         63                  78                 68
# 28     M029      B         71                  86                 76
# 29     M030      B         67                  81                 71
#
#     social_memory  BDNF  CREB1  DRD2  GRIN1      diet  light_hours  \
# 0              70   8.2    6.5   5.8    7.1  standard           12
# 1              73   8.5    6.8   5.6    7.4  standard           12
# 2              68   7.9    6.3   5.9    6.9  standard           12
# 3              71   8.3    6.6   5.7    7.2  enriched           12
# 4              69   8.1    6.4   5.8    7.0  standard           12
# 5              74   8.6    6.9   5.5    7.5  enriched           12
# 6              67   7.8    6.2   6.0    6.8  high_fat           12
# 7              70   8.2    6.5   5.7    7.1  standard           12
# 8              72   8.4    6.7   5.6    7.3  enriched           12
# 9              66   7.7    6.1   6.1    6.7  high_fat           12
# 10             69   8.1    6.4   5.8    7.0  standard           12
# 11             71   8.3    6.6   5.7    7.2  standard           12
# 12             68   7.9    6.3   5.9    6.9  high_fat           12
# 13             73   8.5    6.8   5.5    7.4  enriched           12
# 14             70   8.2    6.5   5.7    7.1  standard           12
# 15             62   6.8    7.2   6.5    6.2  standard           12
# 16             65   7.1    7.5   6.3    6.5  standard           12
# 17             59   6.5    6.9   6.7    5.9  standard           12
# 18             63   6.9    7.3   6.4    6.3  enriched           12
# 19             61   6.7    7.1   6.6    6.1  standard           12
# 20             66   7.2    7.6   6.2    6.6  enriched           12
# 21             58   6.4    6.8   6.8    5.8  high_fat           12
# 22             64   7.0    7.4   6.4    6.4  standard           12
# 23             67   7.3    7.7   6.1    6.7  enriched           12
# 24             57   6.3    6.7   6.9    5.7  high_fat           12
# 25             62   6.8    7.2   6.5    6.2  standard           12
# 26             64   7.0    7.4   6.3    6.4  standard           12
# 27             60   6.6    7.0   6.6    6.0  high_fat           12
# 28             68   7.4    7.8   6.0    6.8  enriched           12
# 29             63   6.9    7.3   6.4    6.3  standard           12
#
#    exercise_wheel  age_weeks  weight_g
# 0             yes         12      28.5
# 1             yes         14      29.2
# 2              no         11      27.8
# 3             yes         13      28.1
# 4              no         12      28.9
# 5             yes         15      29.5
# 6              no         10      30.2
# 7             yes         13      28.4
# 8             yes         14      28.8
# 9              no         11      31.1
# 10             no         12      28.6
# 11            yes         13      28.3
# 12             no         10      30.5
# 13            yes         15      29.1
# 14            yes         12      28.7
# 15            yes         12      26.5
# 16            yes         14      27.2
# 17             no         11      25.8
# 18            yes         13      26.1
# 19             no         12      26.9
# 20            yes         15      27.5
# 21             no         10      28.2
# 22            yes         13      26.4
# 23            yes         14      26.8
# 24             no         11      29.1
# 25             no         12      26.6
# 26            yes         13      26.3
# 27             no         10      28.5
# 28            yes         15      27.1
# 29            yes         12      26.7

# %%
# Dataset overview
print("Shape:", mice.shape)
print("\nColumns:", list(mice.columns))
# Out:
# Shape: (120, 15)
#
# Columns: ['mouse_id', 'strain', 'maze_test', 'object_recognition', 'fear_conditioning', 'social_memory', 'BDNF', 'CREB1', 'DRD2', 'GRIN1', 'diet', 'light_hours', 'exercise_wheel', 'age_weeks', 'weight_g']

# %%
# Mice per strain
mice['strain'].value_counts()#.sort_index()
# Out:
# strain
# A    15
# B    15
# C    15
# D    15
# E    15
# F    15
# G    15
# H    15
# Name: count, dtype: int64

# %%
# Summary statistics
mice.describe()
# Out:
#         maze_test  object_recognition  fear_conditioning  social_memory  \
# count  120.000000          120.000000         120.000000     120.000000
# mean    69.833333           70.550000          68.658333      70.408333
# std      9.484471            6.900067           8.486763       8.064338
# min     50.000000           53.000000          50.000000      55.000000
# 25%     63.000000           66.750000          63.000000      65.000000
# 50%     69.500000           71.000000          69.000000      70.000000
# 75%     76.000000           75.000000          74.000000      75.000000
# max     91.000000           86.000000          88.000000      91.000000
#
#              BDNF       CREB1        DRD2       GRIN1  light_hours  \
# count  120.000000  120.000000  120.000000  120.000000   120.000000
# mean     7.262500    6.740833    6.325000    7.153333    12.000000
# std      1.009373    0.831168    0.673914    0.842558     2.008386
# min      5.300000    5.000000    4.700000    5.500000     8.000000
# 25%      6.500000    6.100000    5.800000    6.575000    12.000000
# 50%      7.200000    6.750000    6.400000    7.100000    12.000000
# 75%      7.900000    7.400000    6.800000    7.625000    12.000000
# max      9.600000    8.400000    7.600000    9.100000    16.000000
#
#         age_weeks    weight_g
# count  120.000000  120.000000
# mean    12.466667   28.984167
# std      1.549916    2.043477
# min     10.000000   25.300000
# 25%     11.000000   27.275000
# 50%     12.000000   28.750000
# 75%     14.000000   30.525000
# max     15.000000   34.100000

# %%
# Check categorical variables
print("Diets:", mice['diet'].unique())
print("Light hours:", mice['light_hours'].unique())
print("Exercise wheel:", mice['exercise_wheel'].unique())
# Out:
# Diets: ['standard' 'enriched' 'high_fat']
# Light hours: [12 16  8]
# Exercise wheel: ['yes' 'no']

# %% [markdown]
# ---
#
# ## Strain-specific Characteristics
#
# Each strain has different cognitive strengths:

# %%
# Mean scores per strain
strain_means = mice.groupby('strain')[['maze_test', 'object_recognition',
                                        'fear_conditioning', 'social_memory']].mean().round(1)
strain_means
# Out:
#         maze_test  object_recognition  fear_conditioning  social_memory
# strain
# A            78.7                72.2               65.1           70.1
# B            65.8                80.6               70.6           62.6
# C            55.8                58.6               82.6           75.6
# D            70.6                70.6               70.6           70.6
# E            85.8                65.6               55.6           60.6
# F            60.8                75.6               75.6           85.6
# G            72.6                68.6               60.6           65.6
# H            68.6                72.6               68.6           72.6

# %%
# Visualize strain differences
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

tests = ['maze_test', 'object_recognition', 'fear_conditioning', 'social_memory']

for i, test in enumerate(tests):
    ax = axes[i // 2, i % 2]
    sns.boxplot(data=mice, x=test, y='strain', ax=ax)
    ax.set_title(test)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Question 1: Is strain A better at maze navigation than strain B?

# %%
ab = mice[mice['strain'].isin(['A', 'B'])]

ab.groupby('strain')['maze_test'].mean()
# Out:
# strain
# A    78.666667
# B    65.800000
# Name: maze_test, dtype: float64

# %% [markdown]
# #### Diagram

# %%
 #sns.boxplot(data=ab, x='strain', y='maze_test', palette='pastel')
 sns.boxplot(
     data=ab,
     x='strain',
     y='maze_test',
     hue='strain',
     palette='pastel',
     legend=False
)
#sns.boxplot(data=ab, x='strain', y='maze_test')
# Out:
# <Axes: xlabel='strain', ylabel='maze_test'>

# %% [markdown]
# #### A  mean = 78.666667   B mean = 65.800000
# #### As we can see from both the mean value and the diagram, strain A performs better in the maze test than strain B.
